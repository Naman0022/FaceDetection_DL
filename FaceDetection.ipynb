# %% [markdown]
# ## Installing Dependencies

# %% [markdown]
# ### tensorflow

# %% [markdown]
# tensorflow-gpu is now included in tensorflow
#
# pip install "tensorflow<2.11"

# %% [markdown]
# ### Other

# %% [markdown]
# pip install labelme
#
# pip install  matplotlib
#
# pip install albumentations
#
# pip install opencv-python

# %%
# %pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.14.5 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from opencv-python==4.5.5.64) (1.24.4)
# Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install  matplotlib==3.6.2
# Out:
# Collecting matplotlib==3.6.2
#   Using cached matplotlib-3.6.2-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.6.2)
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib==3.6.2)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.6.2)
#   Using cached fonttools-4.51.0-cp38-cp38-win_amd64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.6.2)
#   Using cached kiwisolver-1.4.5-cp38-cp38-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.19 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib==3.6.2) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib==3.6.2) (24.0)
# Collecting pillow>=6.2.0 (from matplotlib==3.6.2)
#   Using cached pillow-10.3.0-cp38-cp38-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.6.2)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib==3.6.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.6.2) (1.16.0)
# Using cached matplotlib-3.6.2-cp38-cp38-win_amd64.whl (7.2 MB)
# Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.51.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Using cached kiwisolver-1.4.5-cp38-cp38-win_amd64.whl (56 kB)
# Using cached pillow-10.3.0-cp38-cp38-win_amd64.whl (2.5 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.6.2 pillow-10.3.0 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow==2.10.1
# Out:
# Collecting tensorflow==2.10.1
#   Using cached tensorflow-2.10.1-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.10.1)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.10.1)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=2.0 (from tensorflow==2.10.1)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.10.1)
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.10.1)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow==2.10.1)
#   Using cached h5py-3.11.0-cp38-cp38-win_amd64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.10.1)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.10.1)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.20 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from tensorflow==2.10.1) (1.24.4)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.10.1)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from tensorflow==2.10.1) (24.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.10.1)
#   Using cached protobuf-3.19.6-cp38-cp38-win_amd64.whl.metadata (807 bytes)
# Requirement already satisfied: setuptools in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from tensorflow==2.10.1) (56.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from tensorflow==2.10.1) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.10.1)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from tensorflow==2.10.1) (4.11.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.10.1)
#   Using cached wrapt-1.16.0-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.10.1)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp38-cp38-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.10.1)
#   Using cached grpcio-1.63.0-cp38-cp38-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow==2.10.1)
#   Using cached tensorboard-2.10.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow==2.10.1)
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.11,>=2.10.0 (from tensorflow==2.10.1)
#   Using cached keras-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.10.1)
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (7.1.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: zipp>=0.5 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.18.1)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.10.1-cp38-cp38-win_amd64.whl (455.9 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.63.0-cp38-cp38-win_amd64.whl (3.9 MB)
# Using cached h5py-3.11.0-cp38-cp38-win_amd64.whl (3.0 MB)
# Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached protobuf-3.19.6-cp38-cp38-win_amd64.whl (896 kB)
# Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Using cached tensorflow_io_gcs_filesystem-0.31.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached wrapt-1.16.0-cp38-cp38-win_amd64.whl (37 kB)
# Using cached google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Using cached werkzeug-3.0.2-py3-none-any.whl (226 kB)
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp38-cp38-win_amd64.whl (99 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: tensorboard-plugin-wit, libclang, keras, flatbuffers, wrapt, wheel, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, MarkupSafe, keras-preprocessing, idna, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, markdown, astunparse, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 flatbuffers-24.3.25 gast-0.4.0 google-auth-2.29.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.63.0 h5py-3.11.0 idna-3.7 keras-2.10.0 keras-preprocessing-1.1.2 libclang-18.1.1 markdown-3.6 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.6.0 pyasn1-modules-0.4.0 requests-2.31.0 requests-oauthlib-2.0.0 rsa-4.9 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.1 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0 urllib3-2.2.1 werkzeug-3.0.2 wheel-0.43.0 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-1.4.4-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.24.4 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from albumentations) (1.24.4)
# Collecting scipy>=1.10.0 (from albumentations)
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Collecting scikit-image>=0.21.0 (from albumentations)
#   Using cached scikit_image-0.21.0-cp38-cp38-win_amd64.whl.metadata (14 kB)
# Collecting PyYAML (from albumentations)
#   Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from albumentations) (4.11.0)
# Collecting scikit-learn>=1.3.2 (from albumentations)
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl.metadata (11 kB)
# Collecting pydantic>=2.6.4 (from albumentations)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/107.3 kB 667.8 kB/s eta 0:00:01
#      ---------------------------- -------- 81.9/107.3 kB 919.0 kB/s eta 0:00:01
#      ------------------------------------ 107.3/107.3 kB 776.7 kB/s eta 0:00:00
# Collecting opencv-python-headless>=4.9.0 (from albumentations)
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.6.4->albumentations)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic>=2.6.4->albumentations)
#   Downloading pydantic_core-2.18.2-cp38-none-win_amd64.whl.metadata (6.7 kB)
# Collecting networkx>=2.8 (from scikit-image>=0.21.0->albumentations)
#   Using cached networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pillow>=9.0.1 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image>=0.21.0->albumentations) (10.3.0)
# Collecting imageio>=2.27 (from scikit-image>=0.21.0->albumentations)
#   Using cached imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.21.0->albumentations)
#   Using cached tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image>=0.21.0->albumentations)
#   Using cached PyWavelets-1.4.1-cp38-cp38-win_amd64.whl.metadata (1.9 kB)
# Requirement already satisfied: packaging>=21 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image>=0.21.0->albumentations) (24.0)
# Collecting lazy_loader>=0.2 (from scikit-image>=0.21.0->albumentations)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting joblib>=1.1.1 (from scikit-learn>=1.3.2->albumentations)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=1.3.2->albumentations)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading albumentations-1.4.4-py3-none-any.whl (150 kB)
#    ---------------------------------------- 0.0/150.4 kB ? eta -:--:--
#    ------------------------ --------------- 92.2/150.4 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 150.4/150.4 kB 1.8 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.5 MB 4.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.3/38.5 MB 2.7 MB/s eta 0:00:15
#     --------------------------------------- 0.5/38.5 MB 3.8 MB/s eta 0:00:11
#     --------------------------------------- 0.6/38.5 MB 3.9 MB/s eta 0:00:10
#     --------------------------------------- 0.6/38.5 MB 3.9 MB/s eta 0:00:10
#     --------------------------------------- 0.6/38.5 MB 3.9 MB/s eta 0:00:10
#     --------------------------------------- 0.6/38.5 MB 3.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.4/38.5 MB 3.5 MB/s eta 0:00:11
#    - -------------------------------------- 1.5/38.5 MB 3.5 MB/s eta 0:00:11
#    - -------------------------------------- 1.7/38.5 MB 3.6 MB/s eta 0:00:11
#    -- ------------------------------------- 2.0/38.5 MB 3.7 MB/s eta 0:00:10
#    -- ------------------------------------- 2.1/38.5 MB 3.5 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1/38.5 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/409.3 kB ? eta -:--:--
#    --------- ------------------------------ 92.2/409.3 kB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 194.6/409.3 kB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 194.6/409.3 kB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 194.6/409.3 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 409.3/409.3 kB 1.5 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp38-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.9 MB 1.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/1.9 MB 553.0 kB/s eta 0:00:03
#    --------------- ------------------------ 0.7/1.9 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.9 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.9 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.9 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.9 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/1.9 MB 902.8 kB/s eta 0:00:02
#    ------------------------------ --------- 1.5/1.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/1.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/1.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.9 MB/s eta 0:00:00
# Using cached scikit_image-0.21.0-cp38-cp38-win_amd64.whl (22.7 MB)
# Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.3 MB 4.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/9.3 MB 3.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/9.3 MB 3.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/9.3 MB 3.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.3 MB 4.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/9.3 MB 4.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/9.3 MB 3.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.3 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.4/9.3 MB 3.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 3.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.3 MB 3.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/9.3 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.3 MB 3.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.8/9.3 MB 3.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.3 MB 3.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.0/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.1/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------ --------------------- 4.4/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------- -------------------- 4.4/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------- -------------------- 4.4/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------- -------------------- 4.4/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------- -------------------- 4.4/9.3 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.3 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.3 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.3 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.8/9.3 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.3 MB 3.3 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.3 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.6/9.3 MB 3.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.4/9.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.4/9.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.4/9.3 MB 3.3 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.2/9.3 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.3 MB/s eta 0:00:00
# Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Using cached PyYAML-6.0.1-cp38-cp38-win_amd64.whl (157 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached imageio-2.34.1-py3-none-any.whl (313 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ------------ --------------------------- 92.2/301.8 kB 1.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 133.1/301.8 kB 2.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 215.0/301.8 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 301.8/301.8 kB 1.7 MB/s eta 0:00:00
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Using cached PyWavelets-1.4.1-cp38-cp38-win_amd64.whl (4.2 MB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Installing collected packages: tifffile, threadpoolctl, scipy, PyYAML, PyWavelets, pydantic-core, opencv-python-headless, networkx, lazy_loader, joblib, imageio, annotated-types, scikit-learn, scikit-image, pydantic, albumentations
# Successfully installed PyWavelets-1.4.1 PyYAML-6.0.1 albumentations-1.4.4 annotated-types-0.6.0 imageio-2.34.1 joblib-1.4.2 lazy_loader-0.4 networkx-3.1 opencv-python-headless-4.9.0.80 pydantic-2.7.1 pydantic-core-2.18.2 scikit-image-0.21.0 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.5.0 tifffile-2023.7.10
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Collect Images using open cv & Annotations

# %% [markdown]
# ### Collecting Images

# %%
import os
import time
import uuid # uniform unique identifier
import cv2

# %%
IMAGES_PATH = os.path.join('data','images')
number_images = 30

# %%
cap = cv2.VideoCapture(0)
time.sleep(0.5)
for imgnum in range(number_images):
    print("Collecting images {}".format(imgnum))
    ret,frame = cap.read()
    imgname = os.path.join(IMAGES_PATH,f"{str(uuid.uuid1())}.jpg")
    cv2.imwrite(imgname,frame)
    cv2.imshow('frame',frame)
    time.sleep(0.5)

    if cv2.waitKey(1) & 0XFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images 0
# Collecting images 1
# Collecting images 2
# Collecting images 3
# Collecting images 4
# Collecting images 5
# Collecting images 6
# Collecting images 7
# Collecting images 8
# Collecting images 9
# Collecting images 10
# Collecting images 11
# Collecting images 12
# Collecting images 13
# Collecting images 14
# Collecting images 15
# Collecting images 16
# Collecting images 17
# Collecting images 18
# Collecting images 19
# Collecting images 20
# Collecting images 21
# Collecting images 22
# Collecting images 23
# Collecting images 24
# Collecting images 25
# Collecting images 26
# Collecting images 27
# Collecting images 28
# Collecting images 29

# %% [markdown]
# ### Annotations

# %%
# %pip install labelme
# Out:
# Collecting labelme
#   Using cached labelme-5.4.1-py3-none-any.whl
# Collecting gdown (from labelme)
#   Using cached gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting imgviz>=1.7.5 (from labelme)
#   Using cached imgviz-1.7.5-py3-none-any.whl
# Requirement already satisfied: matplotlib in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (3.6.2)
# Collecting natsort>=7.1.0 (from labelme)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (1.24.4)
# Collecting onnxruntime!=1.16.0,>=1.14.1 (from labelme)
#   Using cached onnxruntime-1.17.3-cp38-cp38-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: Pillow>=2.8 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (10.3.0)
# Requirement already satisfied: PyYAML in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (6.0.1)
# Collecting qtpy!=1.11.2 (from labelme)
#   Using cached QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scikit-image in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (0.21.0)
# Requirement already satisfied: termcolor in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (2.4.0)
# Collecting PyQt5!=5.15.3,!=5.15.4 (from labelme)
#   Using cached PyQt5-5.15.10-cp37-abi3-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: colorama in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from labelme) (0.4.6)
# Collecting coloredlogs (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (24.3.25)
# Requirement already satisfied: packaging in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (24.0)
# Requirement already satisfied: protobuf in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (3.19.6)
# Collecting sympy (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5!=5.15.3,!=5.15.4->labelme)
#   Using cached PyQt5_sip-12.13.0-cp38-cp38-win_amd64.whl.metadata (524 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5!=5.15.3,!=5.15.4->labelme)
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Collecting beautifulsoup4 (from gdown->labelme)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown->labelme)
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests[socks] in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from gdown->labelme) (2.31.0)
# Collecting tqdm (from gdown->labelme)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib->labelme) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib->labelme) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib->labelme) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib->labelme) (1.4.5)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib->labelme) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from matplotlib->labelme) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.8 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image->labelme) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image->labelme) (3.1)
# Requirement already satisfied: imageio>=2.27 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image->labelme) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image->labelme) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image->labelme) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from scikit-image->labelme) (0.4)
# Requirement already satisfied: six>=1.5 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->labelme) (1.16.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown->labelme)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from requests[socks]->gdown->labelme) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from requests[socks]->gdown->labelme) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from requests[socks]->gdown->labelme) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\code\python\face_recognition_dl\.venv\lib\site-packages (from requests[socks]->gdown->labelme) (2024.2.2)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->labelme)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting mpmath>=0.19 (from sympy->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Using cached pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached onnxruntime-1.17.3-cp38-cp38-win_amd64.whl (5.6 MB)
# Using cached PyQt5-5.15.10-cp37-abi3-win_amd64.whl (6.8 MB)
# Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Using cached gdown-5.1.0-py3-none-any.whl (17 kB)
# Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Using cached PyQt5_sip-12.13.0-cp38-cp38-win_amd64.whl (78 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Installing collected packages: pyreadline3, PyQt5-Qt5, mpmath, tqdm, sympy, soupsieve, qtpy, PySocks, PyQt5-sip, natsort, humanfriendly, filelock, PyQt5, coloredlogs, beautifulsoup4, onnxruntime, imgviz, gdown, labelme
# Successfully installed PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 PySocks-1.7.1 beautifulsoup4-4.12.3 coloredlogs-15.0.1 filelock-3.14.0 gdown-5.1.0 humanfriendly-10.0 imgviz-1.7.5 labelme-5.4.1 mpmath-1.3.0 natsort-8.4.0 onnxruntime-1.17.3 pyreadline3-3.4.1 qtpy-2.4.1 soupsieve-2.5 sympy-1.12 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !labelme
# Out:
# 2024-04-26 22:22:08,265 [INFO   ] __init__:get_config:67- Loading config file from: C:\Users\naman\.labelmerc

# %% [markdown]
# ## Review DataSet and build image loading function

# %% [markdown]
# ### Import TF and Deps

# %%
import tensorflow as tf
import json
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Limit Memory growth

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load Images into pipeline

# %%
images = tf.data.Dataset.list_files('data\\images\\*.jpg')

# %%
images.as_numpy_iterator().next()
# Out:
# b'data\\images\\f4bd5c67-03ea-11ef-811d-5ce42a051d23.jpg'

# %%
def load_image(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
images = images.map(load_image)

# %%
images.as_numpy_iterator().next()
# Out:
# array([[[ 24,  22,  62],
#         [ 16,  15,  57],
#         [ 19,  18,  62],
#         ...,
#         [177, 159, 157],
#         [174, 158, 159],
#         [173, 157, 158]],
#
#        [[ 20,  18,  65],
#         [ 12,  13,  59],
#         [ 12,  14,  63],
#         ...,
#         [179, 161, 161],
#         [176, 160, 161],
#         [175, 159, 160]],
#
#        [[ 11,  13,  70],
#         [  7,   9,  66],
#         [  6,  11,  67],
#         ...,
#         [181, 163, 163],
#         [178, 162, 163],
#         [177, 161, 164]],
#
#        ...,
#
#        [[  1,   2,  69],
#         [  0,   1,  68],
#         [  0,   1,  68],
#         ...,
#         [170, 160, 150],
#         [175, 165, 153],
#         [180, 173, 157]],
#
#        [[  0,   0,  74],
#         [  0,   0,  74],
#         [  0,   1,  78],
#         ...,
#         [172, 164, 153],
#         [176, 168, 155],
#         [180, 174, 158]],
#
#        [[  0,   0,  74],
#         [  0,   0,  77],
#         [  0,   0,  82],
#         ...,
#         [180, 172, 161],
#         [178, 172, 158],
#         [176, 170, 154]]], dtype=uint8)

# %% [markdown]
# ### View raw image with matplotlib

# %%
image_generator = images.batch(4).as_numpy_iterator()

# %%
plot_images = image_generator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, image in enumerate(plot_images):
    ax[idx].imshow(image)
plt.show()

# %% [markdown]
# ## Partition unaugmented Data

# %%
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data',folder,'images')):
        filename = file.split(".")[0] + '.json'
        existing_filepath = os.path.join('data','labels',filename)
        if os.path.exists(existing_filepath):
            new_filepath = os.path.join('data',folder,'labels',filename)
            os.replace(existing_filepath,new_filepath)

# %% [markdown]
# ## Apply Image augmentation

# %% [markdown]
# ### Setup albumentations transformation pipeline

# %%
import albumentations as alb

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450),
                           alb.HorizontalFlip(p=0.5),
                           alb.RandomBrightnessContrast(p=0.2),
                           alb.RandomGamma(p=0.2),
                           alb.RGBShift(p=0.2),
                           alb.VerticalFlip(p=0.5)],
                           bbox_params=alb.BboxParams(format='albumentations',
                                                      label_fields = ['class_labels']))

# %%
cv2.imread(os.path.join('data','train','images','40c01336-03eb-11ef-bdaf-5ce42a051d23.jpg'))

# %% [markdown]
# ### Apply Augmentation and view result

# %%
for partition in ['train','test','val']: 
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)

            coords[0] = label['shapes'][0]['points'][0][0]
            coords[1] = label['shapes'][0]['points'][0][1]
            coords[2] = label['shapes'][0]['points'][1][0]
            coords[3] = label['shapes'][0]['points'][1][1]
            coords = list(np.divide(coords, [640,480,640,480]))

        try: 
            for x in range(60):
                augmented = augmentor(image=img, bboxes=[coords], class_labels=['face'])
                cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image

                if os.path.exists(label_path):
                    if len(augmented['bboxes']) == 0: 
                        annotation['bbox'] = [0,0,0,0]
                        annotation['class'] = 0 
                    else: 
                        annotation['bbox'] = augmented['bboxes'][0]
                        annotation['class'] = 1
                else: 
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0 


                with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)
# Out:
# x_max is less than or equal to x_min for bbox [0.30685763888888895, 0.8657407407407407, 0.0, 0.1845904509079715, 'face'].
# x_max is less than or equal to x_min for bbox [0.18793402777777776, 0.8541666666666666, 0.0, 0.1817993757331993, 'face'].
# x_max is less than or equal to x_min for bbox [0.09939236111111112, 0.923611111111111, 0.0004340277777777679, 0.5335648148148149, 'face'].

# %% [markdown]
# ### Load Augmented Images to Tensorflow Dataset

# %%
train_images = tf.data.Dataset.list_files('aug_data\\train\\images\\*.jpg',shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x,(120,120)))
train_images = train_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('aug_data\\test\\images\\*.jpg',shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x,(120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('aug_data\\val\\images\\*.jpg',shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x,(120,120)))
val_images = val_images.map(lambda x: x/255)

# %% [markdown]
# ## Prepare Labels

# %% [markdown]
# ### Build Label loadng function

# %%
def load_labels(label_path):
    with open(label_path.numpy(),'r', encoding = "utf-8") as f:
        label = json.load(f)

    return [label['class']], label['bbox']

# %% [markdown]
# ### Load labels to tensorflow Dataset

# %%
train_labels = tf.data.Dataset.list_files('aug_data\\train\\labels\\*.json',shuffle=False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
test_labels = tf.data.Dataset.list_files('aug_data\\test\\labels\\*.json',shuffle=False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
val_labels = tf.data.Dataset.list_files('aug_data\\val\\labels\\*.json',shuffle=False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %% [markdown]
# ## Combine Label and image samples

# %% [markdown]
# ### Check Partition lengths

# %%
len(train_images), len(test_images), len(val_images)
# Out:
# (3720, 780, 720)

# %% [markdown]
# ### Create Final Datasets (Images/Labels)

# %%
train = tf.data.Dataset.zip((train_images, train_labels))
train = train.shuffle(5000)
train = train.batch(8)
train = train.prefetch(4)

# %%
test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(1300)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(1000)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()[0].shape
# Out:
# (8, 120, 120, 3)

# %% [markdown]
# ## Build Deep Learning using the functional API

# %% [markdown]
# ### Import Layers and Base Network

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16

# %% [markdown]
# ### Download VGG16

# %%
vgg = VGG16(include_top = False)

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### build Instance of Network

# %%
def build_model(): 
    input_layer = Input(shape=(120,120,3))
    
    vgg = VGG16(include_top=False)(input_layer)

    # Classification Model  
    f1 = GlobalMaxPooling2D()(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)
    
    # Bounding box model
    f2 = GlobalMaxPooling2D()(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)
    
    facetracker = Model(inputs=input_layer, outputs=[class2, regress2])
    return facetracker

# %% [markdown]
# ### Test out our network

# %%
facetracker = build_model()

# %%
facetracker.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 120, 120, 3  0           []
#                                 )]
#
#  vgg16 (Functional)             (None, None, None,   14714688    ['input_2[0][0]']
#                                 512)
#
#  global_max_pooling2d (GlobalMa  (None, 512)         0           ['vgg16[0][0]']
#  xPooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 512)         0           ['vgg16[0][0]']
#  MaxPooling2D)
#
#  dense (Dense)                  (None, 2048)         1050624     ['global_max_pooling2d[0][0]']
#
#  dense_2 (Dense)                (None, 2048)         1050624     ['global_max_pooling2d_1[0][0]']
#
#  dense_1 (Dense)                (None, 1)            2049        ['dense[0][0]']
#
#  dense_3 (Dense)                (None, 4)            8196        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 16,826,181
# Trainable params: 16,826,181
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X, y = train.as_numpy_iterator().next()

# %%
X.shape
# Out:
# (8, 120, 120, 3)

# %%
classes, coords = facetracker.predict(X)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
classes, coords
# Out:
# (array([[0.6005641 ],
#         [0.5863267 ],
#         [0.5703672 ],
#         [0.5417223 ],
#         [0.56600696],
#         [0.52226865],
#         [0.5904607 ],
#         [0.51036566]], dtype=float32),
#  array([[0.43866494, 0.64101565, 0.6111742 , 0.6483889 ],
#         [0.42936125, 0.6449622 , 0.5777351 , 0.5863757 ],
#         [0.4049287 , 0.61606205, 0.5346546 , 0.60739934],
#         [0.47286904, 0.6628819 , 0.5136917 , 0.6090717 ],
#         [0.41507757, 0.58373183, 0.5372848 , 0.526157  ],
#         [0.36920983, 0.56833375, 0.46882358, 0.60523975],
#         [0.44011936, 0.63101554, 0.645739  , 0.5616721 ],
#         [0.44670582, 0.5414889 , 0.53495854, 0.6373371 ]], dtype=float32))

# %% [markdown]
# ## Define Losses and Optimizers

# %% [markdown]
# ### Define optimizer and LR

# %%
len(train)
# Out:
# 465

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75-1)/batches_per_epoch

# %%
#Apply optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay = lr_decay)

# %% [markdown]
# ### Create localization loss

# %%
def localization_loss(y_true, yhat):            
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))
                  
    h_true = y_true[:,3] - y_true[:,1] 
    w_true = y_true[:,2] - y_true[:,0] 

    h_pred = yhat[:,3] - yhat[:,1] 
    w_pred = yhat[:,2] - yhat[:,0] 
    
    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))
    
    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.BinaryCrossentropy()
regressloss = localization_loss

# %% [markdown]
# ### Test out our loss metrics

# %%
localization_loss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.059329>

# %% [markdown]
# ## Train our Neural Network

# %% [markdown]
# ### Create custom model class

# %%
class FaceTracker(Model): 
    def __init__(self, eyetracker,  **kwargs): 
        super().__init__(**kwargs)
        self.model = eyetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt
    
    def train_step(self, batch, **kwargs): 
        
        X, y = batch
        
        with tf.GradientTape() as tape: 
            classes, coords = self.model(X, training=True)
            
            batch_classloss = self.closs(y[0], classes)
            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
            
            total_loss = batch_localizationloss+0.5*batch_classloss
            
            grad = tape.gradient(total_loss, self.model.trainable_variables)
        
        opt.apply_gradients(zip(grad, self.model.trainable_variables))
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
    
    def test_step(self, batch, **kwargs): 
        X, y = batch
        
        classes, coords = self.model(X, training=False)
        
        batch_classloss = self.closs(y[0], classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss+0.5*batch_classloss
        
        return {"total_loss":total_loss, "class_loss":batch_classloss, "regress_loss":batch_localizationloss}
        
    def call(self, X, **kwargs): 
        return self.model(X, **kwargs)

# %%
model = FaceTracker(facetracker)

# %%
model.compile(opt, classloss, regressloss)

# %% [markdown]
# ### Train

# %%
logdir = 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 465/465 [==============================] - 51s 97ms/step - total_loss: 0.0622 - class_loss: 0.0119 - regress_loss: 0.0562 - val_total_loss: 0.0136 - val_class_loss: 9.6858e-07 - val_regress_loss: 0.0136
# Epoch 2/20
# 465/465 [==============================] - 51s 103ms/step - total_loss: 0.0476 - class_loss: 0.0123 - regress_loss: 0.0415 - val_total_loss: 0.0232 - val_class_loss: 8.1957e-07 - val_regress_loss: 0.0232
# Epoch 3/20
# 465/465 [==============================] - 51s 100ms/step - total_loss: 0.0161 - class_loss: 0.0022 - regress_loss: 0.0150 - val_total_loss: 0.0197 - val_class_loss: 2.3202e-05 - val_regress_loss: 0.0197
# Epoch 4/20
# 465/465 [==============================] - 51s 101ms/step - total_loss: 0.0133 - class_loss: 0.0027 - regress_loss: 0.0120 - val_total_loss: 0.0115 - val_class_loss: 4.6045e-06 - val_regress_loss: 0.0115
# Epoch 5/20
# 465/465 [==============================] - 50s 101ms/step - total_loss: 0.0067 - class_loss: 6.1522e-04 - regress_loss: 0.0064 - val_total_loss: 0.0318 - val_class_loss: 1.8328e-06 - val_regress_loss: 0.0318
# Epoch 6/20
# 465/465 [==============================] - 51s 101ms/step - total_loss: 0.0040 - class_loss: 4.7695e-05 - regress_loss: 0.0040 - val_total_loss: 0.1699 - val_class_loss: 0.0897 - val_regress_loss: 0.1251
# Epoch 7/20
# 465/465 [==============================] - 52s 102ms/step - total_loss: 0.0032 - class_loss: 1.4247e-05 - regress_loss: 0.0032 - val_total_loss: 0.2118 - val_class_loss: 0.1122 - val_regress_loss: 0.1557
# Epoch 8/20
# 465/465 [==============================] - 50s 100ms/step - total_loss: 0.0025 - class_loss: 1.2337e-05 - regress_loss: 0.0025 - val_total_loss: 0.0164 - val_class_loss: 7.5152e-05 - val_regress_loss: 0.0164
# Epoch 9/20
# 465/465 [==============================] - 50s 101ms/step - total_loss: 0.0022 - class_loss: 1.0288e-05 - regress_loss: 0.0022 - val_total_loss: 1.7432 - val_class_loss: 0.8626 - val_regress_loss: 1.3119
#   0.001409544493071735,
#   0.0005899653770029545,
#   0.0005849547451362014],
#  'class_loss': [0.0003672936582006514,
#   0.0003107021620962769,
#   8.836466804496013e-06,
#   2.1159717107366305e-06,
#   5.200554369366728e-06,
#   0.00012387186870910227,
#   6.556587322847918e-06,
#   1.974409315153025e-06,
#   1.1116471796412952e-05,
#   1.0311688129149843e-05,
#   5.8115028878091834e-06,
#   1.8179456446887343e-06,
#   4.08293453801889e-06,
#   2.2316131435218267e-05,
#   8.344675279658986e-07,
#   2.920640554293641e-06,
#   2.8312231847849034e-07,
#   1.1920930376163597e-07,
#   6.258492248889524e-07,
#   2.458692165419052e-07],
#  'regress_loss': [0.019376972690224648,
#   0.015234599821269512,
#   0.00376486056484282,
#   0.006003116257488728,
#   0.0035251611843705177,
#   0.0026703160256147385,
#   0.0017278911545872688,
#   0.0007644176948815584,
#   0.003523514373227954,
#   0.001978832297027111,
#   0.0014387909322977066,
#   0.001385076204314828,
#   0.0009143401402980089,
#   0.0008857430657371879,
#   0.0017163378652185202,
#   0.0009410797501914203,
#   0.0010920120403170586,
#   0.0014094848884269595,
#   0.0005896524526178837,
#   0.0005848318105563521],
#  'val_total_loss': [0.013631049543619156,
#   0.0232233963906765,
#   0.0196647010743618,
#   0.011486366391181946,
#   0.03184463456273079,
#   0.16994141042232513,
#   0.21184422075748444,
#   0.01643718034029007,
#   1.7432221174240112,
#   0.12846311926841736,
#   0.015534346923232079,
#   0.14814317226409912,
#   0.03351760655641556,
#   0.014458172023296356,
#   0.026508860290050507,
#   0.33796608448028564,
#   0.22284471988677979,
#   0.011365346610546112,
#   0.375419557094574,
#   0.005108256824314594],
#  'val_class_loss': [9.685792292657425e-07,
#   8.19565116216836e-07,
#   2.320203566341661e-05,
#   4.604491095960839e-06,
#   1.8328457827010425e-06,
#   0.08966454863548279,
#   0.11221478134393692,
#   7.515226752730086e-05,
#   0.8626002669334412,
#   0.05629996955394745,
#   6.124418632680317e-06,
#   0.06978408247232437,
#   2.8312365429883357e-06,
#   5.066401627118466e-07,
#   4.0233157960756216e-07,
#   0.2581973671913147,
#   0.1672206073999405,
#   2.2202784748515114e-06,
#   0.31129226088523865,
#   1.1920931797249068e-07],
#  'val_regress_loss': [0.013630565255880356,
#   0.023222986608743668,
#   0.01965310052037239,
#   0.011484064161777496,
#   0.03184371814131737,
#   0.12510913610458374,
#   0.15573683381080627,
#   0.016399603337049484,
#   1.3119219541549683,
#   0.10031314194202423,
#   0.015531284734606743,
#   0.11325112730264664,
#   0.03351619094610214,
#   0.01445791870355606,
#   0.02650865912437439,
#   0.2088674008846283,
#   0.13923440873622894,
#   0.01136423647403717,
#   0.21977344155311584,
#   0.005108197219669819]}

# %%
fig, ax = plt.subplots(ncols=3, figsize=(20,5))

ax[0].plot(hist.history['total_loss'], color='teal', label='loss')
ax[0].plot(hist.history['val_total_loss'], color='orange', label='val loss')
ax[0].title.set_text('Loss')
ax[0].legend()

ax[1].plot(hist.history['class_loss'], color='teal', label='class loss')
ax[1].plot(hist.history['val_class_loss'], color='orange', label='val class loss')
ax[1].title.set_text('Classification Loss')
ax[1].legend()

ax[2].plot(hist.history['regress_loss'], color='teal', label='regress loss')
ax[2].plot(hist.history['val_regress_loss'], color='orange', label='val regress loss')
ax[2].title.set_text('Regression Loss')
ax[2].legend()

plt.show()

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### Make Prediction on test set

# %%
test_data = test.as_numpy_iterator()

# %%
test_sample = test_data.next()

# %%
yhat = facetracker.predict(test_sample[0])
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %%
yhat
# Out:
# [array([[1.0000000e+00],
#         [9.9999845e-01],
#         [9.9999988e-01],
#         [9.9999988e-01],
#         [4.9434901e-05],
#         [3.3146640e-05],
#         [1.0000000e+00],
#         [2.0633134e-04]], dtype=float32),
#  array([[6.3347393e-03, 2.0899341e-01, 2.5653780e-01, 5.8322388e-01],
#         [1.5612307e-01, 2.0972468e-01, 4.5564973e-01, 5.6789470e-01],
#         [1.9373582e-01, 5.4743880e-01, 4.4050306e-01, 8.8836521e-01],
#         [7.7824527e-01, 2.8564537e-01, 9.9604023e-01, 7.4825609e-01],
#         [1.1832792e-03, 1.9293864e-03, 1.1566129e-03, 2.6526670e-03],
#         [1.1231124e-03, 1.4377403e-03, 9.3092653e-04, 2.1782874e-03],
#         [6.5826988e-03, 4.1901818e-01, 1.8436274e-01, 7.8109068e-01],
#         [2.4741490e-03, 5.3451010e-03, 2.8806317e-03, 7.9160379e-03]],
#        dtype=float32)]

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4): 
    sample_image = test_sample[0][idx]
    sample_coords = yhat[1][idx]
    
    if yhat[0][idx] > 0.5:
        cv2.rectangle(sample_image,
                       list(np.multiply(sample_coords[:2], [120,120]).astype(int)),
                       tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)), (255,0,0), 2)
    
    ax[idx].imshow(sample_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Save Model

# %%
from tensorflow.keras.models import load_model

# %%
facetracker.save('facetracker.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
facetracker = load_model('facetracker.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Realtime Detection

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
facetracker=load_model('facetracker.h5')
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _ , frame = cap.read()
    frame = frame[50:500, 50:500,:]
    frame = cv2.flip(frame, 1) 
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120,120))
    
    yhat = facetracker.predict(np.expand_dims(resized/255,0))
    sample_coords = yhat[1][0]
    
    if yhat[0] > 0.9: 
        # Controls the main rectangle
        cv2.rectangle(frame, 
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)), 
                            (255,0,0), 2)
        # Controls the label rectangle
        cv2.rectangle(frame, 
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int), 
                                    [0,-30])),
                      tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                    [80,0])), 
                            (255,0,0), -1)
        
        # Controls the text rendered
        cv2.putText(frame, 'face', tuple(np.add(np.multiply(sample_coords[:2], [450,450]).astype(int),
                                               [0,-5])),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow('FaceTrack', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
